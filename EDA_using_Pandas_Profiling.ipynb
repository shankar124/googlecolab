# %% [markdown]
# <a href="https://colab.research.google.com/github/shankar124/googlecolab/blob/main/EDA_using_Pandas_Profiling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Install Pandas Profiling

# %%
! pip install https://github.com/pandas-profiling/pandas-profiling/archive/master.zip

# %%
import numpy as np
import pandas as pd

from pandas_profiling import ProfileReport

df= pd.DataFrame(
    np.random.rand(100,5),
    columns=['a','b','c','d','e']
)

# %%
profile = ProfileReport(df, title='Pandas Profiling Report', html={'style':{'full_width' :True}})

# %%
profile

# %%
import pandas as pd

url = 'https://www.basketball-reference.com/leagues/NBA_2019_per_game.html'

html = pd.read_html(url, header = 0)
df2021 = html[0]

## Data Cleaning


raw = df2021.drop(df2021[df2021.Age =='Age'].index)
raw

# %%
profile_NBA = ProfileReport(raw, title='NBA Profiling Report', html={'style':{'full_width' :True}})

# %%
profile_NBA
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
